-- %%
%sql
CREATE SCHEMA IF NOT EXISTS databricks_project1.bronze;

CREATE SCHEMA IF NOT EXISTS databricks_project1.silver;

CREATE SCHEMA IF NOT EXISTS databricks_project1.gold;

CREATE SCHEMA IF NOT EXISTS databricks_project1.common;

-- %%
%sql
SHOW SCHEMAS IN databricks_project1;

-- %%
%sql
USE CATALOG databricks_project1;
USE SCHEMA bronze;

-- %%
SHOW SCHEMAS IN databricks_project1;
